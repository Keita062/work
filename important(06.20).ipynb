# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm

# %%
# データの読み込みと確認
dat = pd.read_csv(r"C:\Users\sk062\Downloads\dat_with_country_all.csv")
print(dat.head(20))
print(dat.tail(20))
# Out:
#     energy    tempo  danceability playlist_genre  loudness  liveness  valence  \
# 0   0.7460  132.310         0.636           rock    -3.785    0.1730   0.4320
# 1   0.8350  129.981         0.572           rock    -6.219    0.0702   0.7950
# 2   0.8040  111.457         0.591           rock    -7.299    0.0818   0.6580
# 3   0.1040   76.474         0.443           jazz   -17.042    0.1910   0.3940
# 4   0.4720   80.487         0.685           jazz    -9.691    0.2240   0.4750
# 5   0.3650  119.347         0.670           jazz   -10.158    0.0575   0.4500
# 6   0.2640  122.482         0.663           jazz   -14.571    0.1000   0.6570
# 7   0.2220  156.364         0.525           jazz   -11.065    0.0510   0.6450
# 8   0.0619   60.705         0.336           jazz   -20.494    0.1100   0.1970
# 9   0.6710  127.359         0.742           jazz    -8.142    0.1220   0.5910
# 10  0.0422  130.436         0.519           jazz   -10.778    0.1240   0.3970
# 11  0.1130   95.063         0.659           jazz   -16.756    0.1790   0.7380
# 12  0.1590   59.385         0.505           jazz   -11.235    0.2120   0.1960
# 13  0.0917   95.068         0.517           jazz   -18.395    0.1080   0.0836
# 14  0.1950  133.918         0.412           jazz   -10.288    0.1060   0.0778
# 15  0.4200  147.143         0.417           jazz   -13.046    0.1850   0.5170
# 16  0.2730   63.423         0.517           jazz   -17.279    0.9790   0.3210
# 17  0.2370  126.222         0.477           jazz   -17.115    0.0974   0.1780
# 18  0.1260  133.998         0.234      classical   -25.427    0.1020   0.2160
# 19  0.0306  125.610         0.289      classical   -30.790    0.1020   0.1180
#
#                         track_artist  time_signature  speechiness  ...   key  \
# 0       Creedence Clearwater Revival             4.0       0.0393  ...   0.0
# 1                          Van Halen             4.0       0.0317  ...   0.0
# 2                       Stevie Nicks             4.0       0.0454  ...   0.0
# 3   Ella Fitzgerald, Louis Armstrong             4.0       0.1010  ...   0.0
# 4                     Galt MacDermot             4.0       0.0298  ...   9.0
# 5         Frank Sinatra, Count Basie             4.0       0.0566  ...   0.0
# 6   Ella Fitzgerald, Louis Armstrong             4.0       0.0914  ...   0.0
# 7                      Benny Goodman             4.0       0.0373  ...  10.0
# 8                       Kenny Dorham             4.0       0.0363  ...   5.0
# 9                      Horace Silver             4.0       0.0407  ...   5.0
# 10                       Gene Ammons             3.0       0.0537  ...   1.0
# 11                   Coleman Hawkins             4.0       0.0569  ...  10.0
# 12                Stanley Turrentine             4.0       0.0336  ...   7.0
# 13             Esbjörn Svensson Trio             4.0       0.0336  ...   0.0
# 14                      Roy Hargrove             4.0       0.0331  ...   8.0
# 15                     John Coltrane             4.0       0.0600  ...   0.0
# 16                      Dave Brubeck             4.0       0.0627  ...  10.0
# 17                 Mary Lou Williams             3.0       0.0321  ...   4.0
# 18  Johann Sebastian Bach, Lang Lang             4.0       0.0446  ...   0.0
# 19  Ludwig van Beethoven, Igor Levit             3.0       0.0446  ...   9.0
#
#    duration_ms acousticness                      id playlist_subgenre  \
# 0     138053.0       0.0648  5e6x5YRnMJIKvYpZxLqdpH           classic
# 1     241600.0       0.1710  5FqYA8KfiwsQvyBI4IamnY           classic
# 2     329413.0       0.3270  5LNiqEqpDc8TuqPy79kDBu           classic
# 3     185160.0       0.9130  78MI7mu1LV1k4IA2HzKmHe           classic
# 4     205720.0       0.7850  6MN6yRVriszuyAVlyF8ndB           classic
# 5     147147.0       0.5250  2dR5WkrpwylTuT3jRWNufa           classic
# 6     354533.0       0.7060  33jt3kYWjQzqn3xyYQ5ZEh           classic
# 7     195533.0       0.8360  1xUJ1mdLAysxNBtO9w3J2g           classic
# 8     190400.0       0.9850  3GOZbK2epuHzCt5YvvVFHO           classic
# 9     438280.0       0.7940  1CDBaGlisZlOJzvx88lL8A           classic
# 10    252947.0       0.9660  6rK27cC9hX0e1Chrnxo9Vn           classic
# 11    182360.0       0.9760  2xm9ihELo6xwrRKrBbPql9           classic
# 12    295200.0       0.9460  7ysmJhXFQtiBQlk6EZ6sks           classic
# 13    267173.0       0.8760  72PqmnVj86bfTnkFiQ9Mx9           classic
# 14    372493.0       0.9000  1czzmAtPTw287TyMQEfCfg           classic
# 15    287844.0       0.1860  1ZXu0ib26kWfQQngREMcU2           classic
# 16    354573.0       0.8660  1GZD0TZJHmdQaZsucHBmWT           classic
# 17    280481.0       0.9470  2qswPLZD9CbUoSidGNyxwm           classic
# 18    139307.0       0.9890  4SFBV7SRNG2e2kyL1F6kjU         essential
# 19    212067.0       0.9870  3zLTPuucd3e6TxZnu2dlVS         essential
#
#               type             playlist_id popularity  genre6  country
# 0   audio_features  37i9dQZF1DWXRqgorJj26U        low    rock       US
# 1   audio_features  37i9dQZF1DWXRqgorJj26U        low    rock       US
# 2   audio_features  37i9dQZF1DWXRqgorJj26U        low    rock       US
# 3   audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 4   audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       CA
# 5   audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 6   audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 7   audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 8   audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 9   audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 10  audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 11  audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 12  audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 13  audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       SE
# 14  audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 15  audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 16  audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 17  audio_features  37i9dQZF1DXbITWG1ZJKYt        low  others       US
# 18  audio_features  37i9dQZF1DWWEJlAGA9gs0        low  others    DE|CN
# 19  audio_features  37i9dQZF1DWWEJlAGA9gs0        low  others       DE
#
# [20 rows x 32 columns]
#       energy    tempo  danceability playlist_genre  loudness  liveness  \
# 4766   0.627  118.093         0.788     electronic    -9.072    0.2320
# 4767   0.708  130.081         0.872     electronic    -7.472    0.0998
# 4768   0.569  115.030         0.772     electronic    -7.006    0.1170
# 4769   0.709  130.081         0.872     electronic    -7.472    0.0998
# 4770   0.533  102.025         0.863          indie    -7.986    0.0794
# 4771   0.873   97.960         0.621          indie    -3.067    0.0824
# 4772   0.924  168.017         0.598          indie    -4.974    0.1700
# 4773   0.664  118.018         0.731          indie    -5.474    0.1330
# 4774   0.655   92.900         0.649          latin    -5.534    0.2200
# 4775   0.781  107.007         0.811          latin    -6.333    0.1210
# 4776   0.503   99.970         0.792          latin    -8.044    0.0959
# 4777   0.501  103.993         0.637          latin    -6.148    0.0990
# 4778   0.485  100.053         0.843          latin    -8.735    0.1070
# 4779   0.549  123.879         0.613          latin    -8.187    0.1160
# 4780   0.649  113.009         0.788          latin    -9.674    0.1200
# 4781   0.422  124.357         0.573          latin    -7.621    0.1020
# 4782   0.725  105.016         0.711          latin    -8.315    0.1100
# 4783   0.809   99.005         0.724          latin    -5.022    0.0765
# 4784   0.642   83.389         0.463          latin    -4.474    0.0686
# 4785   0.890  126.881         0.645            pop    -4.985    0.3760
#
#       valence                 track_artist  time_signature  speechiness  ...  \
# 4766    0.909                     Carbonne             4.0       0.0751  ...
# 4767    0.308       Tiakola, Ryflo, Oskoow             4.0       0.1760  ...
# 4768    0.525  Tiakola, Genezio, Prototype             4.0       0.0620  ...
# 4769    0.309       Tiakola, Ryflo, Oskoow             4.0       0.1760  ...
# 4770    0.738                      Parcels             4.0       0.0484  ...
# 4771    0.873                  Tame Impala             4.0       0.0369  ...
# 4772    0.611                   Royel Otis             4.0       0.0623  ...
# 4773    0.661                  Tame Impala             4.0       0.0302  ...
# 4774    0.793                       Oxlade             4.0       0.0652  ...
# 4775    0.824                         Rema             4.0       0.0428  ...
# 4776    0.381                   Ayra Starr             4.0       0.0626  ...
# 4777    0.431                 Rotimi, Wale             4.0       0.1870  ...
# 4778    0.689                  Drake, Tems             4.0       0.1950  ...
# 4779    0.780                         Tems             5.0       0.2310  ...
# 4780    0.229            Davido, Musa Keys             4.0       0.0532  ...
# 4781    0.693                     Libianca             5.0       0.0678  ...
# 4782    0.530                     Omah Lay             4.0       0.0941  ...
# 4783    0.606                 Davido, FAVE             4.0       0.0929  ...
# 4784    0.339          Future, Drake, Tems             4.0       0.3400  ...
# 4785    0.421    Alan Walker, Ina Wroldsen             4.0       0.1280  ...
#
#        key duration_ms acousticness                      id playlist_subgenre  \
# 4766   0.0    165894.0      0.69300  6IcsbETuviVu6UTiBTcxY4            french
# 4767  10.0    169846.0      0.33600  6C0SXfD7rR46MpWK5VJSEw            french
# 4768   6.0    246979.0      0.23500  6JCjcuo4VKAP4bHhbHj6fe            french
# 4769  10.0    169846.0      0.33600  2PYlRGF5Wi5sDobsLH5gLX            french
# 4770   5.0    249957.0      0.29100  66tkDkPsznE5zIHNt4QkXB        australian
# 4771   5.0    237800.0      0.04060  5hM5arv9KDbCHS0k9uqwjr        australian
# 4772   6.0    162339.0      0.02050  2B664ulJSVBd6B8SAY3Wux        australian
# 4773   0.0    239267.0      0.00307  6RZmhpvukfyeSURhf4kZ0d        australian
# 4774  10.0    147581.0      0.30700  2WigMwGJysIh9fRnSJvpjn        afro-latin
# 4775  11.0    219813.0      0.37600  6hgoYQDUcPyCz7LcTUHKxa        afro-latin
# 4776   1.0    185093.0      0.03690  1rrqJ9QkOBYJlsZgqqwxgB        afro-latin
# 4777   0.0    185461.0      0.22900  6XM53PbvlzhuNtJZtpl7RP        afro-latin
# 4778  10.0    192418.0      0.18100  08XWh5c0BMyD1nKVxxl91z        afro-latin
# 4779   9.0    180000.0      0.09700  2dFqK2ZkYB9Xc47gr3xXWl        afro-latin
# 4780   2.0    169912.0      0.25300  2kaH2Z8ezDUKf6fNw250rZ        afro-latin
# 4781  10.0    184791.0      0.55100  26b3oVLrRUaaybJulow9kz        afro-latin
# 4782   3.0    183057.0      0.42400  1wADwLSkYhrSmy4vdy6BRn        afro-latin
# 4783   6.0    194040.0      0.18200  7vKXc90NT5WBm3UTT4iTVG        afro-latin
# 4784   1.0    189893.0      0.31400  59nOXPmaKlBfGMDeOVGrIK        afro-latin
# 4785   6.0    205087.0      0.25900  2GE3k8I0Sbh0puCjI15KGy            scandi
#
#                 type             playlist_id popularity      genre6   country
# 4766  audio_features  58zteW83Lvl8e158fCCFVN       high  electronic        FR
# 4767  audio_features  58zteW83Lvl8e158fCCFVN       high  electronic        FR
# 4768  audio_features  58zteW83Lvl8e158fCCFVN       high  electronic        FR
# 4769  audio_features  58zteW83Lvl8e158fCCFVN       high  electronic        FR
# 4770  audio_features  37i9dQZF1EIcLyY4fNNQaC       high      others        AU
# 4771  audio_features  37i9dQZF1EIcLyY4fNNQaC       high      others        AU
# 4772  audio_features  37i9dQZF1EIcLyY4fNNQaC       high      others        AU
# 4773  audio_features  37i9dQZF1EIcLyY4fNNQaC       high      others        AU
# 4774  audio_features  0oU30cCr8klmMsuOKHDLkh       high       latin        NG
# 4775  audio_features  0oU30cCr8klmMsuOKHDLkh       high       latin        NG
# 4776  audio_features  0oU30cCr8klmMsuOKHDLkh       high       latin        NG
# 4777  audio_features  0oU30cCr8klmMsuOKHDLkh       high       latin        US
# 4778  audio_features  0oU30cCr8klmMsuOKHDLkh       high       latin     CA|NG
# 4779  audio_features  0oU30cCr8klmMsuOKHDLkh       high       latin        NG
# 4780  audio_features  0oU30cCr8klmMsuOKHDLkh       high       latin       NaN
# 4781  audio_features  0oU30cCr8klmMsuOKHDLkh       high       latin        US
# 4782  audio_features  0oU30cCr8klmMsuOKHDLkh       high       latin        NG
# 4783  audio_features  0oU30cCr8klmMsuOKHDLkh       high       latin        NG
# 4784  audio_features  0oU30cCr8klmMsuOKHDLkh       high       latin  US|CA|NG
# 4785  audio_features  59z06GgF6TTDbm5cr1RZUC       high         pop        NO
#
# [20 rows x 32 columns]

# %%
# 欠損値の除去
dat = dat.dropna(subset=['popularity', 'energy'])

# 人気をカテゴリカル→数値へ変換
dat['pop'] = pd.Categorical(dat['popularity'], categories=['low', 'high'])
dat['ybin'] = (dat['pop'] == 'high').astype(int)

# ベクトル作成
y = dat['ybin'].values                  # 0/1の目的変数
x = dat['energy'].values               # 説明変数
X = np.column_stack((np.ones(len(x)), x))  # デザイン行列
n = len(y)

# %%
plt.figure(figsize=(8, 5))
sns.stripplot(x='energy', y='pop', data=dat, jitter=0.12, alpha=0.3, size=4)
plt.title("Energy vs. Popularity (jittered)")
plt.xlabel("Energy")
plt.ylabel("Popularity")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# statsmodelsでGLM
model = sm.GLM(dat['ybin'], X, family=sm.families.Binomial())
fit_glm = model.fit()
print(fit_glm.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                   ybin   No. Observations:                 4785
# Model:                            GLM   Df Residuals:                     4783
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  Logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2953.2
# Date:                Fri, 20 Jun 2025   Deviance:                       5906.3
# Time:                        09:57:05   Pearson chi2:                 4.70e+03
# No. Iterations:                     4   Pseudo R-squ. (CS):            0.06147
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.0249      0.095    -21.242      0.000      -2.212      -1.838
# x1             2.3269      0.143     16.325      0.000       2.048       2.606
# ==============================================================================

# %%
b = np.array([np.log(np.mean(y) / (1 - np.mean(y))), 0.0])  # 初期値（切片のみ）
eps = 1e-8
maxit = 100

for k in range(maxit):
    eta = X @ b
    mu = 1 / (1 + np.exp(-eta))
    w = mu * (1 - mu)
    z = eta + (y - mu) / w

    sqrtw = np.sqrt(w)
    Xw = X * sqrtw[:, np.newaxis]
    zw = z * sqrtw
    XtWX = Xw.T @ Xw
    XtWz = Xw.T @ zw

    b_new = np.linalg.solve(XtWX, XtWz)

    print(f"Iter {k+1:2d} : β0 = {b_new[0]:.6f} , β1 = {b_new[1]:.6f}")

    if np.max(np.abs(b_new - b)) < eps:
        print(">>> 収束 <<<")
        break
    b = b_new

beta_hat = b_new
vcov_hat = np.linalg.inv(XtWX)
se_hat = np.sqrt(np.diag(vcov_hat))
# Out:
# Iter  1 : β0 = -1.819314 , β1 = 2.066695
# Iter  2 : β0 = -2.016670 , β1 = 2.315923
# Iter  3 : β0 = -2.024888 , β1 = 2.326903
# Iter  4 : β0 = -2.024902 , β1 = 2.326921
# Iter  5 : β0 = -2.024902 , β1 = 2.326921
# >>> 収束 <<<

# %%
# GLM係数とSE
glm_coef = fit_glm.params.values
glm_se = np.sqrt(np.diag(fit_glm.cov_params()))

print("\n=== Coefficient Comparison ===")
print(pd.DataFrame({
    "Hand_IRLS": beta_hat,
    "GLM": glm_coef
}, index=["Intercept", "Energy"]))

print("\n=== SE Comparison ===")
print(pd.DataFrame({
    "Hand_IRLS": se_hat,
    "GLM": glm_se
}, index=["Intercept", "Energy"]))
# Out:
# === Coefficient Comparison ===
#            Hand_IRLS       GLM
# Intercept  -2.024902 -2.024902
# Energy      2.326921  2.326921
#
# === SE Comparison ===
#            Hand_IRLS       GLM
# Intercept   0.095325  0.095325
# Energy      0.142537  0.142537

# %%
list(dat.columns)
# Out:
# ['energy',
#  'tempo',
#  'danceability',
#  'playlist_genre',
#  'loudness',
#  'liveness',
#  'valence',
#  'track_artist',
#  'time_signature',
#  'speechiness',
#  'track_popularity',
#  'track_href',
#  'uri',
#  'track_album_name',
#  'playlist_name',
#  'analysis_url',
#  'track_id',
#  'track_name',
#  'track_album_release_date',
#  'instrumentalness',
#  'track_album_id',
#  'mode',
#  'key',
#  'duration_ms',
#  'acousticness',
#  'id',
#  'playlist_subgenre',
#  'type',
#  'playlist_id',
#  'popularity',
#  'genre6',
#  'country',
#  'pop',
#  'ybin']

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from scipy.special import expit  # sigmoid
import statsmodels.api as sm

# 例：必要なカラムだけ抽出
X_cols = ['energy', 'danceability', 'valence', 'loudness']
df = dat.dropna(subset=X_cols + ['ybin'])  # 欠損除去

# 標準化（オプション）
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df[X_cols])

# 定数項追加
X = sm.add_constant(X_scaled)
y = df['ybin'].astype(int)

# IRLSによるロジスティック回帰（statsmodelsが内部でIRLSを使う）
model = sm.Logit(y, X)
result = model.fit()

print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.595390
#          Iterations 7
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                   ybin   No. Observations:                 4785
# Model:                          Logit   Df Residuals:                     4780
# Method:                           MLE   Df Model:                            4
# Date:                Fri, 20 Jun 2025   Pseudo R-squ.:                 0.08245
# Time:                        10:15:30   Log-Likelihood:                -2848.9
# converged:                       True   LL-Null:                       -3104.9
# Covariance Type:            nonrobust   LLR p-value:                1.708e-109
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.8122      0.038    -21.533      0.000      -0.886      -0.738
# x1            -0.0977      0.061     -1.599      0.110      -0.217       0.022
# x2            -0.0854      0.042     -2.023      0.043      -0.168      -0.003
# x3             0.0002      0.039      0.004      0.997      -0.076       0.077
# x4             1.2838      0.102     12.632      0.000       1.085       1.483
# ==============================================================================

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler

# === データの準備 ===
X_raw = df[X_cols].values
y = df['ybin'].values.reshape(-1, 1)

# 標準化
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X_raw)

# 切片項を追加
X = np.hstack([np.ones((X_scaled.shape[0], 1)), X_scaled])
n, d = X.shape

# === IRLS 実装 ===
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

def IRLS(X, y, max_iter=100, tol=1e-6):
    beta = np.zeros((X.shape[1], 1))
    
    for i in range(max_iter):
        z = X @ beta
        p = sigmoid(z)
        W = np.diagflat(p * (1 - p))
        try:
            # 疑似目的変数 z_tilde
            z_tilde = z + np.linalg.pinv(W) @ (y - p)
            # IRLS update
            beta_new = np.linalg.pinv(X.T @ W @ X) @ (X.T @ W @ z_tilde)
        except np.linalg.LinAlgError:
            print("数値計算でエラーが発生しました（特異行列）")
            break
        
        # 収束判定
        if np.linalg.norm(beta_new - beta) < tol:
            print(f"収束しました（{i+1}回目）")
            break
        
        beta = beta_new
        
    return beta

# モデル学習
beta_hat = IRLS(X, y)

# 結果表示
feature_names = ['Intercept'] + X_cols
for name, coef in zip(feature_names, beta_hat.flatten()):
    print(f"{name:>12}: {coef:.4f}")
# Out:
# 収束しました（6回目）
#    Intercept: -0.8122
#       energy: -0.0977
# danceability: -0.0854
#      valence: 0.0002
#     loudness: 1.2838
