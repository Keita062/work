# %%
# !pip install japanize-matplotlib openpyxl

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import japanize_matplotlib
import matplotlib
import collections

# 日本語フォントの設定
matplotlib.rcParams['font.family'] = 'Meiryo'  # Windows用
#最大表示列数の指定（ここでは50列を指定）
pd.set_option('display.max_columns', 50)

# %%
df_summer = pd.read_excel(r"C:\Users\sk062\Downloads\【鴨居】2024（夏） PREMIUM TEACHERS アンケート（回答）.xlsx")
df_winter = pd.read_excel(r"C:\Users\sk062\Downloads\【鴨居】2024（冬） PREMIUM TEACHERS アンケート（回答）.xlsx")
df_summer = df_summer.fillna(0)
df_winter = df_winter.fillna(0)
df_summer = df_summer.drop(df_summer.columns[[0, 1]], axis=1)
df_winter = df_winter.drop(df_winter.columns[0], axis=1)
df_summer.iloc[:, 0] = df_summer.iloc[:, 0].str.replace("\u3000", "", regex=True)
df_winter.iloc[:, 0] = df_winter.iloc[:, 0].str.replace("\u3000", "", regex=True)
df_winter.replace('大岩 瑞季', 0, inplace=True)

# %%
# df_summer.info()

# %%
#print("夏の一番元気に挨拶してくれている先生は誰ですか？を数える",collections.Counter(df_summer.iloc[:,2]))
#print("冬の一番元気に挨拶してくれている先生は誰ですか？を数える",collections.Counter(df_winter.iloc[:,2]))
#print("夏の一番話を聞いてくれている先生は誰ですか？を数える",collections.Counter(df_summer.iloc[:,3]))
#print("冬の一番話を聞いてくれている先生は誰ですか？を数える",collections.Counter(df_winter.iloc[:,3]))
#print("夏の一番面倒をみてくれていると思う先生は誰ですか？を数える",collections.Counter(df_summer.iloc[:,4]))
#print("冬の一番面倒をみてくれていると思う先生は誰ですか？を数える",collections.Counter(df_winter.iloc[:,4]))
#print("夏の一番英語を教えてほしい先生は誰ですか？を数える",collections.Counter(df_summer.iloc[:,5]))
#print("冬の一番英語を教えてほしい先生は誰ですか？を数える",collections.Counter(df_winter.iloc[:,5]))
#print("夏の二番目に英語を教えてほしい先生は誰ですか？を数える",collections.Counter(df_summer.iloc[:,7]))
#print("冬の二番目に英語を教えてほしい先生は誰ですか？を数える",collections.Counter(df_winter.iloc[:,7]))
#print("夏の一番算数・数学・理科を教えてほしい先生は誰ですか？を数える",collections.Counter(df_summer.iloc[:,9]))
#print("冬の一番算数・数学・理科を教えてほしい先生は誰ですか？を数える",collections.Counter(df_winter.iloc[:,9]))
#print("夏の二番目に算数・数学・理科を教えてほしい先生は誰ですか？を数える",collections.Counter(df_summer.iloc[:,11]))
#print("冬の二番目に算数・数学・理科を教えてほしい先生は誰ですか？を数える",collections.Counter(df_winter.iloc[:,11]))
#print("夏の一番国語・社会を教えてほしい先生は誰ですか？を数える",collections.Counter(df_summer.iloc[:,13]))
#print("冬の一番国語・社会を教えてほしい先生は誰ですか？を数える",collections.Counter(df_winter.iloc[:,13]))
#print("夏の二番国語・社会を教えてほしい先生は誰ですか？を数える",collections.Counter(df_summer.iloc[:,15]))
#print("冬の二番国語・社会を教えてほしい先生は誰ですか？を数える",collections.Counter(df_winter.iloc[:,15]))

# %%
#columns_to_plot = [2, 3, 4, 5, 7, 9, 11, 13, 15]

# 各列の棒グラフを出力
#for col in columns_to_plot:
#    column_name = df_summer.columns[col]  # 列名を取得
#    plt.figure(figsize=(8, 5))
#    value_counts = df_summer.iloc[:, col].value_counts()
#    value_counts.plot(kind='bar', color='black', edgecolor='black')

#    plt.xlabel('Values')
#    plt.ylabel('Count')
#    plt.title(f' {column_name} in summer')
#    plt.xticks(rotation=45)
#    plt.ylim(0, 30)  # y軸の範囲を 0-25 に固定
#    plt.yticks(range(0, 31, 5))  # 5刻みの目盛り
#    plt.grid(axis='y', linestyle='--', alpha=0.7)

#    plt.show()

# %%
#columns_to_plot = [2, 3, 4, 5, 7, 9, 11, 13, 15]

# 各列の棒グラフを出力
#for col in columns_to_plot:
#    column_name = df_winter.columns[col]  # 列名を取得
#    plt.figure(figsize=(8, 5))
#    value_counts = df_winter.iloc[:, col].value_counts()
#    value_counts.plot(kind='bar', color='black', edgecolor='black')

#    plt.xlabel('Values')
#    plt.ylabel('Count')
#    plt.title(f'{column_name} in winter')
#    plt.xticks(rotation=45)
#    plt.ylim(0, 30)  # y軸の範囲を 0-25 に固定
#    plt.yticks(range(0, 31, 5))  # 5刻みの目盛り
#    plt.grid(axis='y', linestyle='--', alpha=0.7)

#    plt.show()

# %%
#Existing_df_summer = df_summer.copy()
#Existing_df_winter = df_winter.copy()
#Existing_df_summer.replace('見澤 優貴', 0, inplace=True)
#Existing_df_summer.replace('永礼 もも香', 0, inplace=True)
#Existing_df_summer.replace('関野 優一郎', 0, inplace=True)
#Existing_df_summer.replace('大堀 愛実', 0, inplace=True)
#Existing_df_winter.replace('大堀 愛実', 0, inplace=True)
#Existing_df_winter.replace('大岩 瑞季', 0, inplace=True)

# %%
#columns_to_plot = [2, 3, 4, 5, 7, 9, 11, 13, 15]

# 各列の棒グラフを出力
#for col in columns_to_plot:
#    column_name = Existing_df_summer.columns[col]  # 列名を取得
#    plt.figure(figsize=(8, 5))
#    value_counts = df_winter.iloc[:, col].value_counts()
    
    # インデックスを文字列型に変換
#    value_counts.index = value_counts.index.astype(str)
    
    # 棒の幅を決定（0の値には幅0を設定）
#    bar_widths = [0 if v == 0 else 0.8 for v in value_counts]

    # 棒グラフを描画
#    bars = plt.bar(value_counts.index, value_counts.values, width=bar_widths, color='black', edgecolor='black')

#    plt.xlabel('Values')
#    plt.ylabel('Count')
#    plt.title(f'既存の講師のみ{column_name} in summer')
#    plt.xticks(rotation=45)
#    plt.ylim(0, 30)  # y軸の範囲を 0-30 に固定
#    plt.yticks(range(0, 31, 5))  # 5刻みの目盛り
#    plt.grid(axis='y', linestyle='--', alpha=0.7)

#    plt.show()

# %%
#columns_to_plot = [2, 3, 4, 5, 7, 9, 11, 13, 15]

# 各列の棒グラフを出力
#for col in columns_to_plot:
#    column_name = Existing_df_winter.columns[col]  # 列名を取得
#    plt.figure(figsize=(8, 5))
#    value_counts = df_winter.iloc[:, col].value_counts()
    
    # インデックスを文字列型に変換
#    value_counts.index = value_counts.index.astype(str)
    
    # 棒の幅を決定（0の値には幅0を設定）
#    bar_widths = [0 if v == 0 else 0.8 for v in value_counts]

    # 棒グラフを描画
#    bars = plt.bar(value_counts.index, value_counts.values, width=bar_widths, color='black', edgecolor='black')

#    plt.xlabel('Values')
#    plt.ylabel('Count')
#    plt.title(f'既存の講師のみ{column_name} in summer')
#    plt.xticks(rotation=45)
#    plt.ylim(0, 30)  # y軸の範囲を 0-30 に固定
#    plt.yticks(range(0, 31, 5))  # 5刻みの目盛り
#    plt.grid(axis='y', linestyle='--', alpha=0.7)

#    plt.show()

# %%
#print("夏の一番元気に挨拶してくれている先生は誰ですか？を数える",collections.Counter(Existing_df_summer.iloc[:,2]))
#print("冬の一番元気に挨拶してくれている先生は誰ですか？を数える",collections.Counter(Existing_df_winter.iloc[:,2]))
#print("夏の一番話を聞いてくれている先生は誰ですか？を数える",collections.Counter(Existing_df_summer.iloc[:,3]))
#print("冬の一番話を聞いてくれている先生は誰ですか？を数える",collections.Counter(Existing_df_winter.iloc[:,3]))
#print("夏の一番面倒をみてくれていると思う先生は誰ですか？を数える",collections.Counter(Existing_df_summer.iloc[:,4]))
#print("冬の一番面倒をみてくれていると思う先生は誰ですか？を数える",collections.Counter(Existing_df_winter.iloc[:,4]))
#print("夏の一番英語を教えてほしい先生は誰ですか？を数える",collections.Counter(Existing_df_summer.iloc[:,5]))
#print("冬の一番英語を教えてほしい先生は誰ですか？を数える",collections.Counter(Existing_df_winter.iloc[:,5]))
#print("夏の二番目に英語を教えてほしい先生は誰ですか？を数える",collections.Counter(Existing_df_summer.iloc[:,7]))
#print("冬の二番目に英語を教えてほしい先生は誰ですか？を数える",collections.Counter(Existing_df_winter.iloc[:,7]))
#print("夏の一番算数・数学・理科を教えてほしい先生は誰ですか？を数える",collections.Counter(Existing_df_summer.iloc[:,9]))
#print("冬の一番算数・数学・理科を教えてほしい先生は誰ですか？を数える",collections.Counter(Existing_df_winter.iloc[:,9]))
#print("夏の二番目に算数・数学・理科を教えてほしい先生は誰ですか？を数える",collections.Counter(Existing_df_summer.iloc[:,11]))
#print("冬の二番目に算数・数学・理科を教えてほしい先生は誰ですか？を数える",collections.Counter(Existing_df_winter.iloc[:,11]))
#print("夏の一番国語・社会を教えてほしい先生は誰ですか？を数える",collections.Counter(Existing_df_summer.iloc[:,13]))
#print("冬の一番国語・社会を教えてほしい先生は誰ですか？を数える",collections.Counter(Existing_df_winter.iloc[:,13]))
#print("夏の二番国語・社会を教えてほしい先生は誰ですか？を数える",collections.Counter(Existing_df_summer.iloc[:,15]))
#print("冬の二番国語・社会を教えてほしい先生は誰ですか？を数える",collections.Counter(Existing_df_winter.iloc[:,15]))

# %%
#columns_to_plot = [2, 3, 4, 5, 7, 9, 11, 13, 15]

# 2列表示用にサブプロットを設定（行数は列数 / 2）
#n_rows = (len(columns_to_plot) + 1) // 2  # 列数に応じて行数を計算
#fig, axes = plt.subplots(n_rows, 2, figsize=(15, 5 * n_rows))  # 2列に配置
#axes = axes.flatten()  # axes を1次元配列に変換

# 各列の棒グラフをサブプロットに描画
#for idx, col in enumerate(columns_to_plot):
#    column_name = Existing_df_summer.columns[col]  # 列名を取得
#    value_counts = df_winter.iloc[:, col].value_counts()
    
    # インデックスを文字列型に変換
#    value_counts.index = value_counts.index.astype(str)
    
    # 棒の幅を決定（0の値には幅0を設定）
#    bar_widths = [0 if v == 0 else 0.8 for v in value_counts]

    # サブプロットに棒グラフを描画
#    ax = axes[idx]
#    ax.bar(value_counts.index, value_counts.values, width=bar_widths, color='black', edgecolor='black')

#    ax.set_xlabel('Values')
#    ax.set_ylabel('Count')
#    ax.set_title(f'既存の講師のみ {column_name} in summer')
#    ax.set_xticklabels(value_counts.index, rotation=45)
#    ax.set_ylim(0, 30)  # y軸の範囲を 0-30 に固定
#    ax.set_yticks(range(0, 31, 5))  # 5刻みの目盛り
#    ax.grid(axis='y', linestyle='--', alpha=0.7)

# レイアウトを調整
#plt.tight_layout()

# グラフを指定のパスに保存
#save_path = r"C:\Users\sk062\OneDrive\デスクトップ\1st.png"
#plt.savefig(save_path)

# 保存した後に表示
#plt.show()

# %%
# columns_to_plot = [2, 3, 4, 5, 7, 9, 11, 13, 15]

# 2列表示用にサブプロットを設定（行数は列数 / 2）
# n_rows = (len(columns_to_plot) + 1) // 2  # 列数に応じて行数を計算
# fig, axes = plt.subplots(n_rows, 2, figsize=(15, 5 * n_rows))  # 2列に配置
# axes = axes.flatten()  # axes を1次元配列に変換

# 各列の棒グラフをサブプロットに描画
# for idx, col in enumerate(columns_to_plot):
#     column_name = Existing_df_winter.columns[col]  # 列名を取得
#     value_counts = Existing_df_winter.iloc[:, col].value_counts()
    
    # インデックスを文字列型に変換
#     value_counts.index = value_counts.index.astype(str)
    
    # 棒の幅を決定（0の値には幅0を設定）
    bar_widths = [0 if v == 0 else 0.8 for v in value_counts]

    # サブプロットに棒グラフを描画
    ax = axes[idx]
    ax.bar(value_counts.index, value_counts.values, width=bar_widths, color='black', edgecolor='black')

    ax.set_xlabel('Values')
    ax.set_ylabel('Count')
    ax.set_title(f'既存の講師のみ {column_name} in winter')
    ax.set_xticklabels(value_counts.index, rotation=45)
    ax.set_ylim(0, 30)  # y軸の範囲を 0-30 に固定
    ax.set_yticks(range(0, 31, 5))  # 5刻みの目盛り
    ax.grid(axis='y', linestyle='--', alpha=0.7)

# レイアウトを調整
plt.tight_layout()

# グラフを指定のパスに保存
save_path = r"C:\Users\sk062\OneDrive\デスクトップ\2nd.png"
plt.savefig(save_path)

# 保存した後に表示
plt.show()
# Out:
# C:\Users\sk062\AppData\Local\Temp\ipykernel_2576\2537464183.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(value_counts.index, rotation=45)
# C:\Users\sk062\AppData\Local\Temp\ipykernel_2576\2537464183.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(value_counts.index, rotation=45)
# C:\Users\sk062\AppData\Local\Temp\ipykernel_2576\2537464183.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(value_counts.index, rotation=45)
# C:\Users\sk062\AppData\Local\Temp\ipykernel_2576\2537464183.py:26: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# ...

# %%
Existing_df_winter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   生徒さま氏名                         45 non-null     object
#  1   生徒さま学年                         45 non-null     object
#  2   １．一番元気に挨拶してくれている先生は誰ですか？       45 non-null     object
#  3   ２．一番話を聞いてくれている先生は誰ですか？         45 non-null     object
#  4   ３．一番面倒をみてくれていると思う先生は誰ですか？      45 non-null     object
#  5   ４．一番英語を教えてほしい先生は誰ですか？          45 non-null     object
#  6   理由                             45 non-null     object
#  7   ４．二番目に英語を教えてほしい先生は誰ですか？        45 non-null     object
#  8   理由.1                           45 non-null     object
#  9   ５．一番算数・数学・理科を教えてほしい先生は誰ですか？    45 non-null     object
#  10  理由.2                           45 non-null     object
#  11  ５．二番目に算数・数学・理科を教えてほしい先生は誰ですか？  45 non-null     object
# ...

# %%
df_1 = Existing_df_summer.copy()
df_2 = Existing_df_winter.copy()

df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   生徒さま氏名                         42 non-null     object
#  1   生徒さま学年                         42 non-null     object
#  2   １．一番元気に挨拶してくれている先生は誰ですか？       42 non-null     object
#  3   ２．一番話を聞いてくれている先生は誰ですか？         42 non-null     object
#  4   ３．一番面倒をみてくれていると思う先生は誰ですか？      42 non-null     object
#  5   ４．一番英語を教えてほしい先生は誰ですか？          42 non-null     object
#  6   理由                             42 non-null     object
#  7   ４．二番目に英語を教えてほしい先生は誰ですか？        42 non-null     object
#  8   理由.1                           42 non-null     object
#  9   ５．一番算数・数学・理科を教えてほしい先生は誰ですか？    42 non-null     object
#  10  理由.2                           42 non-null     object
#  11  ５．二番目に算数・数学・理科を教えてほしい先生は誰ですか？  42 non-null     object
# ...

# %%
# 特定の行をilocで選択
df_subset_in_summer = Existing_df_summer.iloc[[2, 3, 4, 5, 7, 9, 11, 13, 15]]

# 選択した行の値の出現回数をカウント
value_counts_in_summer = df_subset_in_summer.stack().value_counts()

# 結果を表示
value_counts_in_summer
# Out:
# 鈴木 啓太                28
# 0                    27
# 斉藤 佑弥                21
# 白石 陽大                 6
# 石原 聖奈                 6
#                      ..
# 面白く分かりやすく教えてくれるから     1
# とても分かりやすいから           1
# 坂本希実                  1
# 中1                    1
# 結構教えてくれそうだから          1
# Name: count, Length: 62, dtype: int64
