# %% [markdown]
# <a href="https://colab.research.google.com/github/Keita062/work/blob/main/Eye(miss11.11).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Eye = pd.read_csv('/content/DO - コピー.csv')

# %%
print(Eye.columns)
print(Eye.describe())
print(Eye.info())
print(Eye.isnull( ).sum())
print(Eye.dtypes)
print(Eye.shape)
# Out:
# Index(['DataCount', 'TIME(Y/M/D h:m:s)', ' milliSeconds', 'leftX', 'leftY',
#        'rightX', 'rightY', 'leftPSize', 'rightPSize'],
#       dtype='object')
#          DataCount   milliSeconds        leftX        leftY       rightX  \
# count  2858.000000    2858.000000  2858.000000  2858.000000  2858.000000
# mean   1556.110567     494.896431   913.467135   429.747194   932.054804
# std     843.728373     288.513020   304.413384   160.314291   267.368785
# min       2.000000       2.000000     0.000000     0.000000     0.000000
# 25%     839.250000     238.000000   850.724300   385.813675   852.527725
# 50%    1553.500000     502.000000   956.161000   435.757200   949.878100
# 75%    2267.750000     738.000000  1045.538750   500.421400  1032.484500
# max    3162.000000     988.000000  1793.382000  1241.945000  1804.003000
#
#             rightY    leftPSize   rightPSize
# count  2858.000000  2858.000000  2858.000000
# mean    459.598823    18.733915    18.783683
# ...

# %%
Eye.head()
# Out:
#    DataCount TIME(Y/M/D h:m:s)   milliSeconds     leftX     leftY    rightX  \
# 0          2   2024/11/2 18:13            535  770.9930  542.5826  744.4664
# 1          3   2024/11/2 18:13            581  783.1512  470.1998  757.0742
# 2          4   2024/11/2 18:13            612  759.7722  475.1764  756.7003
# 3          5   2024/11/2 18:13            644  775.8635  485.2859  749.9686
# 4          6   2024/11/2 18:13            676  778.5135  487.6267  752.9910
#
#      rightY  leftPSize  rightPSize
# 0  567.8753    16.6672     17.0328
# 1  569.6154    14.4211     14.9066
# 2  557.0222    14.3276     14.7274
# 3  561.2388    14.6416     14.8207
# 4  566.4250    14.2361     15.1852

# %%
count_zeros = (Eye.iloc[:, 2:9] == 0).sum(axis=1)

if (count_zeros >= 4).any():
    Eye.replace(0, pd.NA).ffill(axis=0)
else:
    Eye.iloc[:, 2:9] = 0
# Out:
# <ipython-input-30-d29f0701ca1d>:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   Eye.replace(0, pd.NA).ffill(axis=0)

# %%
Eye.head()
# Out:
#    DataCount TIME(Y/M/D h:m:s)   milliSeconds     leftX     leftY    rightX  \
# 0          2   2024/11/2 18:13            535  770.9930  542.5826  744.4664
# 1          3   2024/11/2 18:13            581  783.1512  470.1998  757.0742
# 2          4   2024/11/2 18:13            612  759.7722  475.1764  756.7003
# 3          5   2024/11/2 18:13            644  775.8635  485.2859  749.9686
# 4          6   2024/11/2 18:13            676  778.5135  487.6267  752.9910
#
#      rightY  leftPSize  rightPSize
# 0  567.8753    16.6672     17.0328
# 1  569.6154    14.4211     14.9066
# 2  557.0222    14.3276     14.7274
# 3  561.2388    14.6416     14.8207
# 4  566.4250    14.2361     15.1852

# %%
Eye_1 = Eye.to_csv('Eye_1.csv', index=False)
